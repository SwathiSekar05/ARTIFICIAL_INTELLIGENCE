# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
Dataset=pd.read_csv('insurance_pre.csv')
Dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
Dataset=pd.get_dummies(Dataset,dtype=int,drop_first=True)
Dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
Independent=Dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
Independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
Dependent=Dataset[['charges']]
Dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
#without train and test set split

# %%
#standardisation
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
Independent=sc.fit_transform(Independent)

# %%
from sklearn.svm import SVR

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {'kernel':['rbf','poly','sigmoid','linear'],'C':[10,50,100,150,200],'gamma':['auto','scale']}
grid = GridSearchCV(SVR(), param_grid, refit = True, verbose = 3,n_jobs=-1)
grid.fit(Independent,Dependent)
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# C:\Users\sswat\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [10, 50, 100, 150, 200],
#                          'gamma': ['auto', 'scale'],
#                          'kernel': ['rbf', 'poly', 'sigmoid', 'linear']},
#              verbose=3)

# %%
#If we print and see...It will show it in dictionary format(Poor readability)
re=grid.cv_results_
re
# Out:
# {'mean_fit_time': array([0.10381455, 0.08557086, 0.11089196, 0.07533956, 0.09771452,
#         0.07905126, 0.11685958, 0.07700372, 0.10013466, 0.08256159,
#         0.10703654, 0.08384309, 0.0978611 , 0.07790766, 0.10383801,
#         0.08263164, 0.1057086 , 0.07869763, 0.11289482, 0.08277826,
#         0.09111352, 0.08320012, 0.11295767, 0.08015046, 0.1102757 ,
#         0.08389196, 0.10547071, 0.07613907, 0.11263142, 0.0799623 ,
#         0.1126595 , 0.08890524, 0.10257196, 0.09068689, 0.11490107,
#         0.07886705, 0.10366287, 0.09646826, 0.10708575, 0.08017416]),
#  'std_fit_time': array([0.01686705, 0.01266247, 0.01043869, 0.0070199 , 0.00961561,
#         0.01194655, 0.0151771 , 0.00576896, 0.00694492, 0.01396572,
#         0.01171571, 0.01446515, 0.00780692, 0.00730986, 0.00588295,
#         0.01154194, 0.01703009, 0.00435887, 0.01295819, 0.00762292,
#         0.00338967, 0.00226911, 0.00420217, 0.00249046, 0.01805546,
# ...

# %%
grid_predictions = grid.predict(Independent)

# %%
#to view it in table format
Table=pd.DataFrame. from_dict(re)
Table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        0.103815      0.016867         0.045904        0.002745      10
# 1        0.085571      0.012662         0.011997        0.001038      10
# 2        0.110892      0.010439         0.018872        0.001300      10
# 3        0.075340      0.007020         0.013780        0.003420      10
# 4        0.097715      0.009616         0.045753        0.002639      10
# 5        0.079051      0.011947         0.013959        0.002475      10
# 6        0.116860      0.015177         0.020163        0.001230      10
# 7        0.077004      0.005769         0.014982        0.003484      10
# 8        0.100135      0.006945         0.043607        0.004447      50
# 9        0.082562      0.013966         0.011808        0.001794      50
# 10       0.107037      0.011716         0.021194        0.002946      50
# 11       0.083843      0.014465         0.011370        0.000734      50
# ...

# %%
from sklearn.metrics import r2_score
R_score=r2_score(Dependent,grid_predictions)
R_score
# Out:
# 0.7636552483140329

# %%
print(' R_score for best parameter{}:'.format(grid.best_params_))
# Out:
#  R_score for best parameter{'C': 200, 'gamma': 'auto', 'kernel': 'poly'}:
