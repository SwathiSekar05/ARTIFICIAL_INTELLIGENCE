# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
Dataset=pd.read_csv('insurance_pre.csv')

# %%
Dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
Dataset=pd.get_dummies(Dataset,dtype=int,drop_first=True)
Dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
Independent=Dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
Independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
Dependent=Dataset[[ 'charges']]
Dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
#standardisation

from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
Independent=sc.fit_transform(Independent)

# %%
#GridSearchCV

from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
param_grid = {'criterion':['squarred_error','absolute_error','poisson','friedman_mse'],'max_features': [None,'sqrt','log2'],'n_estimators':[50,100]}
grid = GridSearchCV(RandomForestRegressor(), param_grid, refit = True, verbose= 3,n_jobs=-1)

#Substituting 
grid.fit(Independent,Dependent)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# C:\Users\sswat\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:378: FitFailedWarning:
# 30 fits failed out of a total of 120.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 8 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\sswat\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\sswat\AppData\Local\anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py", line 340, in fit
#     self._validate_params()
#   File "C:\Users\sswat\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py", line 600, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\sswat\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 97, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of RandomForestRegressor must be a str among {'friedman_mse', 'poisson', 'absolute_error', 'squared_error'}. Got 'squarred_error' instead.
#
# --------------------------------------------------------------------------------
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\sswat\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\sswat\AppData\Local\anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py", line 340, in fit
#     self._validate_params()
#   File "C:\Users\sswat\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py", line 600, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\sswat\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 97, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of RandomForestRegressor must be a str among {'absolute_error', 'squared_error', 'poisson', 'friedman_mse'}. Got 'squarred_error' instead.
#
# --------------------------------------------------------------------------------
# 3 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\sswat\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\sswat\AppData\Local\anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py", line 340, in fit
#     self._validate_params()
#   File "C:\Users\sswat\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py", line 600, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\sswat\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 97, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of RandomForestRegressor must be a str among {'friedman_mse', 'absolute_error', 'squared_error', 'poisson'}. Got 'squarred_error' instead.
#
# --------------------------------------------------------------------------------
# 15 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\sswat\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\sswat\AppData\Local\anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py", line 340, in fit
#     self._validate_params()
#   File "C:\Users\sswat\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py", line 600, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\sswat\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 97, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of RandomForestRegressor must be a str among {'poisson', 'squared_error', 'absolute_error', 'friedman_mse'}. Got 'squarred_error' instead.
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\sswat\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\sswat\AppData\Local\anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py", line 340, in fit
#     self._validate_params()
#   File "C:\Users\sswat\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py", line 600, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\sswat\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 97, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of RandomForestRegressor must be a str among {'squared_error', 'friedman_mse', 'poisson', 'absolute_error'}. Got 'squarred_error' instead.
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\sswat\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\sswat\AppData\Local\anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py", line 340, in fit
#     self._validate_params()
#   File "C:\Users\sswat\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py", line 600, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\sswat\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 97, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of RandomForestRegressor must be a str among {'absolute_error', 'friedman_mse', 'poisson', 'squared_error'}. Got 'squarred_error' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\sswat\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:952: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan        nan        nan        nan
#  0.8222143  0.8244973  0.83465474 0.83605093 0.83229784 0.83323281
#  0.8289666  0.82693947 0.83438061 0.83393208 0.8306426  0.83308996
#  0.82735407 0.82642751 0.8307455  0.83403281 0.83252811 0.83315849]
#   warnings.warn(
# C:\Users\sswat\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:909: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self.best_estimator_.fit(X, y, **fit_params)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squarred_error', 'absolute_error',
#                                        'poisson', 'friedman_mse'],
#                          'max_features': [None, 'sqrt', 'log2'],
#                          'n_estimators': [50, 100]},
#              verbose=3)

# %%
grid_predictions = grid.predict(Independent)

# %%
re=grid.cv_results_
table=pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.000224      0.000448         0.000000        0.000000
# 1        0.002550      0.003138         0.000000        0.000000
# 2        0.002158      0.002722         0.000000        0.000000
# 3        0.001321      0.000411         0.000000        0.000000
# 4        0.000768      0.000681         0.000000        0.000000
# 5        0.000431      0.000554         0.000000        0.000000
# 6        1.199015      0.107811         0.011530        0.004373
# 7        2.243633      0.144790         0.014652        0.004417
# 8        0.707671      0.031969         0.008266        0.003145
# 9        1.386245      0.097083         0.014782        0.007749
# 10       0.784141      0.043506         0.005408        0.003093
# 11       2.191633      0.699237         0.027277        0.015503
# 12       0.306623      0.034035         0.005907        0.004354
# 13       0.759608      0.215719         0.020507        0.011771
# 14       0.340230      0.136433         0.012849        0.011519
# 15       1.134461      0.111687         0.035741        0.008642
# 16       0.603429      0.060168         0.024214        0.005378
# 17       1.015704      0.062488         0.032603        0.003846
# 18       0.590842      0.033076         0.016211        0.003569
# 19       1.120179      0.076581         0.032384        0.010538
# 20       0.483101      0.036099         0.017322        0.002928
# 21       0.855333      0.054858         0.031782        0.003322
# 22       0.462915      0.032830         0.021838        0.010231
# 23       0.743321      0.062389         0.027455        0.004046
#
#    param_criterion param_max_features param_n_estimators  \
# 0   squarred_error               None                 50
# 1   squarred_error               None                100
# 2   squarred_error               sqrt                 50
# 3   squarred_error               sqrt                100
# 4   squarred_error               log2                 50
# 5   squarred_error               log2                100
# 6   absolute_error               None                 50
# 7   absolute_error               None                100
# 8   absolute_error               sqrt                 50
# 9   absolute_error               sqrt                100
# 10  absolute_error               log2                 50
# 11  absolute_error               log2                100
# 12         poisson               None                 50
# 13         poisson               None                100
# 14         poisson               sqrt                 50
# 15         poisson               sqrt                100
# 16         poisson               log2                 50
# 17         poisson               log2                100
# 18    friedman_mse               None                 50
# 19    friedman_mse               None                100
# 20    friedman_mse               sqrt                 50
# 21    friedman_mse               sqrt                100
# 22    friedman_mse               log2                 50
# 23    friedman_mse               log2                100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squarred_error', 'max_features'...                NaN
# 1   {'criterion': 'squarred_error', 'max_features'...                NaN
# 2   {'criterion': 'squarred_error', 'max_features'...                NaN
# 3   {'criterion': 'squarred_error', 'max_features'...                NaN
# 4   {'criterion': 'squarred_error', 'max_features'...                NaN
# 5   {'criterion': 'squarred_error', 'max_features'...                NaN
# 6   {'criterion': 'absolute_error', 'max_features'...           0.836195
# 7   {'criterion': 'absolute_error', 'max_features'...           0.842943
# 8   {'criterion': 'absolute_error', 'max_features'...           0.855882
# 9   {'criterion': 'absolute_error', 'max_features'...           0.861385
# 10  {'criterion': 'absolute_error', 'max_features'...           0.858162
# 11  {'criterion': 'absolute_error', 'max_features'...           0.861551
# 12  {'criterion': 'poisson', 'max_features': None,...           0.850692
# 13  {'criterion': 'poisson', 'max_features': None,...           0.849601
# 14  {'criterion': 'poisson', 'max_features': 'sqrt...           0.853166
# 15  {'criterion': 'poisson', 'max_features': 'sqrt...           0.857354
# 16  {'criterion': 'poisson', 'max_features': 'log2...           0.856707
# 17  {'criterion': 'poisson', 'max_features': 'log2...           0.855014
# 18  {'criterion': 'friedman_mse', 'max_features': ...           0.848549
# 19  {'criterion': 'friedman_mse', 'max_features': ...           0.848962
# 20  {'criterion': 'friedman_mse', 'max_features': ...           0.859554
# 21  {'criterion': 'friedman_mse', 'max_features': ...           0.857878
# 22  {'criterion': 'friedman_mse', 'max_features': ...           0.858782
# 23  {'criterion': 'friedman_mse', 'max_features': ...           0.858769
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0                 NaN                NaN                NaN
# 1                 NaN                NaN                NaN
# 2                 NaN                NaN                NaN
# 3                 NaN                NaN                NaN
# 4                 NaN                NaN                NaN
# 5                 NaN                NaN                NaN
# 6            0.765950           0.851960           0.820182
# 7            0.767041           0.853590           0.822975
# 8            0.781225           0.861556           0.830150
# 9            0.782657           0.859564           0.830730
# 10           0.779537           0.853944           0.826715
# 11           0.780332           0.857422           0.826388
# 12           0.778433           0.850639           0.820402
# 13           0.765799           0.857363           0.817613
# 14           0.784106           0.856932           0.831209
# 15           0.784021           0.860733           0.827603
# 16           0.781481           0.852623           0.826130
# 17           0.781940           0.861382           0.828564
# 18           0.769462           0.859015           0.816572
# 19           0.769957           0.857219           0.818880
# 20           0.774466           0.858130           0.831523
# 21           0.780640           0.861540           0.831297
# 22           0.778314           0.855844           0.827737
# 23           0.778773           0.858840           0.826008
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0                 NaN              NaN             NaN               19
# 1                 NaN              NaN             NaN               19
# 2                 NaN              NaN             NaN               19
# 3                 NaN              NaN             NaN               19
# 4                 NaN              NaN             NaN               19
# 5                 NaN              NaN             NaN               19
# 6            0.836785         0.822214        0.029874               18
# 7            0.835938         0.824497        0.030401               17
# 8            0.844461         0.834655        0.028794                2
# 9            0.845920         0.836051        0.028883                1
# 10           0.843131         0.832298        0.028530               10
# 11           0.840472         0.833233        0.029274                6
# 12           0.844666         0.828967        0.027623               13
# 13           0.844321         0.826939        0.033366               15
# 14           0.846491         0.834381        0.026630                3
# 15           0.839949         0.833932        0.027692                5
# 16           0.836272         0.830643        0.026949               12
# 17           0.838550         0.833090        0.028099                8
# 18           0.843173         0.827354        0.032155               14
# 19           0.837120         0.826428        0.031036               16
# 20           0.830054         0.830745        0.030816               11
# 21           0.838808         0.834033        0.029005                4
# 22           0.841962         0.832528        0.029271                9
# 23           0.843402         0.833158        0.029764                7

# %%
from sklearn.metrics import r2_score
r_score=r2_score(Dependent,grid_predictions)
print("The R_score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter {'criterion': 'absolute_error', 'max_features': 'sqrt', 'n_estimators': 100}:

# %%
#r_score

print('R_score:',r_score)
# Out:
# R_score: 0.9694734640406544
