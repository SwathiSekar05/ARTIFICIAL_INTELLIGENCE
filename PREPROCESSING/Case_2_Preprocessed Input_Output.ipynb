# %%
import pandas as pd

# %%
Dataset=pd.read_csv('insurance_pre.csv')

# %%
Dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
Dataset=pd.get_dummies(Dataset,dtype=int,drop_first=True)
Dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
Independent=Dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
Independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
Dependent=Dataset[[ 'charges']]
Dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(Independent,Dependent,test_size=0.30,random_state=0)

# %%
#standardisation
#Preprocessing both Input and Output

from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

scy=StandardScaler()
Y_train=scy.fit_transform(Y_train)
Y_test=scy.transform(Y_test)

# %%
#GridSearchCV

from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
param_grid = {'criterion':['squarred_error','absolute_error','poisson','friedman_mse'],'max_features': [None,'sqrt','log2'],'n_estimators':[50,100]}
grid = GridSearchCV(RandomForestRegressor(), param_grid, refit = True, verbose= 3,n_jobs=-1)

#Fitting the model
grid.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# C:\Users\sswat\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:378: FitFailedWarning:
# 60 fits failed out of a total of 120.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 15 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\sswat\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\sswat\AppData\Local\anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py", line 340, in fit
#     self._validate_params()
#   File "C:\Users\sswat\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py", line 600, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\sswat\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 97, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of RandomForestRegressor must be a str among {'poisson', 'absolute_error', 'squared_error', 'friedman_mse'}. Got 'squarred_error' instead.
#
# --------------------------------------------------------------------------------
# 9 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\sswat\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\sswat\AppData\Local\anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py", line 340, in fit
#     self._validate_params()
#   File "C:\Users\sswat\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py", line 600, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\sswat\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 97, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of RandomForestRegressor must be a str among {'poisson', 'squared_error', 'absolute_error', 'friedman_mse'}. Got 'squarred_error' instead.
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\sswat\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\sswat\AppData\Local\anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py", line 340, in fit
#     self._validate_params()
#   File "C:\Users\sswat\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py", line 600, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\sswat\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 97, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of RandomForestRegressor must be a str among {'absolute_error', 'friedman_mse', 'poisson', 'squared_error'}. Got 'squarred_error' instead.
#
# --------------------------------------------------------------------------------
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\sswat\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\sswat\AppData\Local\anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py", line 340, in fit
#     self._validate_params()
#   File "C:\Users\sswat\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py", line 600, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\sswat\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 97, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of RandomForestRegressor must be a str among {'friedman_mse', 'squared_error', 'poisson', 'absolute_error'}. Got 'squarred_error' instead.
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\sswat\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\sswat\AppData\Local\anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py", line 340, in fit
#     self._validate_params()
#   File "C:\Users\sswat\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py", line 600, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\sswat\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 97, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of RandomForestRegressor must be a str among {'poisson', 'absolute_error', 'friedman_mse', 'squared_error'}. Got 'squarred_error' instead.
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\sswat\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\sswat\AppData\Local\anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py", line 340, in fit
#     self._validate_params()
#   File "C:\Users\sswat\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py", line 600, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\sswat\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 97, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of RandomForestRegressor must be a str among {'poisson', 'squared_error', 'friedman_mse', 'absolute_error'}. Got 'squarred_error' instead.
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\sswat\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\sswat\AppData\Local\anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py", line 340, in fit
#     self._validate_params()
#   File "C:\Users\sswat\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py", line 600, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\sswat\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 97, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of RandomForestRegressor must be a str among {'absolute_error', 'poisson', 'squared_error', 'friedman_mse'}. Got 'squarred_error' instead.
#
# --------------------------------------------------------------------------------
# 30 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\sswat\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\sswat\AppData\Local\anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py", line 373, in fit
#     raise ValueError(
# ValueError: Some value(s) of y are negative which is not allowed for Poisson regression.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\sswat\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:952: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan        nan        nan        nan
#  0.79587372 0.79629801 0.80672324 0.80826037 0.80796516 0.80877958
#         nan        nan        nan        nan        nan        nan
#  0.80228548 0.80255938 0.80850756 0.81186367 0.81035134 0.81537886]
#   warnings.warn(
# C:\Users\sswat\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:909: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self.best_estimator_.fit(X, y, **fit_params)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squarred_error', 'absolute_error',
#                                        'poisson', 'friedman_mse'],
#                          'max_features': [None, 'sqrt', 'log2'],
#                          'n_estimators': [50, 100]},
#              verbose=3)

# %%
re=grid.cv_results_
Table=pd.DataFrame. from_dict(re)
Table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.000278      0.000343         0.000000        0.000000
# 1        0.000000      0.000000         0.000000        0.000000
# 2        0.000327      0.000273         0.000000        0.000000
# 3        0.000198      0.000243         0.000000        0.000000
# 4        0.000543      0.000322         0.000000        0.000000
# 5        0.000571      0.000475         0.000000        0.000000
# 6        0.703087      0.071295         0.007513        0.007173
# 7        1.509348      0.101911         0.006824        0.004884
# 8        0.458943      0.024183         0.001645        0.002225
# 9        0.892723      0.055592         0.013483        0.002629
# 10       0.487389      0.035665         0.007726        0.004854
# 11       0.884695      0.049467         0.010590        0.006990
# 12       0.005589      0.005683         0.000000        0.000000
# 13       0.004854      0.003389         0.000000        0.000000
# 14       0.010175      0.012366         0.000000        0.000000
# 15       0.001051      0.000388         0.000000        0.000000
# 16       0.000939      0.000131         0.000000        0.000000
# 17       0.001841      0.001445         0.000000        0.000000
# 18       0.197973      0.019399         0.001619        0.002751
# 19       0.353380      0.026518         0.016058        0.004807
# 20       0.141111      0.016528         0.006249        0.007654
# 21       0.269139      0.025825         0.012367        0.007701
# 22       0.137913      0.017743         0.003125        0.006249
# 23       0.225364      0.029722         0.009376        0.007656
#
#    param_criterion param_max_features param_n_estimators  \
# 0   squarred_error               None                 50
# 1   squarred_error               None                100
# 2   squarred_error               sqrt                 50
# 3   squarred_error               sqrt                100
# 4   squarred_error               log2                 50
# 5   squarred_error               log2                100
# 6   absolute_error               None                 50
# 7   absolute_error               None                100
# 8   absolute_error               sqrt                 50
# 9   absolute_error               sqrt                100
# 10  absolute_error               log2                 50
# 11  absolute_error               log2                100
# 12         poisson               None                 50
# 13         poisson               None                100
# 14         poisson               sqrt                 50
# 15         poisson               sqrt                100
# 16         poisson               log2                 50
# 17         poisson               log2                100
# 18    friedman_mse               None                 50
# 19    friedman_mse               None                100
# 20    friedman_mse               sqrt                 50
# 21    friedman_mse               sqrt                100
# 22    friedman_mse               log2                 50
# 23    friedman_mse               log2                100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squarred_error', 'max_features'...                NaN
# 1   {'criterion': 'squarred_error', 'max_features'...                NaN
# 2   {'criterion': 'squarred_error', 'max_features'...                NaN
# 3   {'criterion': 'squarred_error', 'max_features'...                NaN
# 4   {'criterion': 'squarred_error', 'max_features'...                NaN
# 5   {'criterion': 'squarred_error', 'max_features'...                NaN
# 6   {'criterion': 'absolute_error', 'max_features'...           0.844681
# 7   {'criterion': 'absolute_error', 'max_features'...           0.843126
# 8   {'criterion': 'absolute_error', 'max_features'...           0.850340
# 9   {'criterion': 'absolute_error', 'max_features'...           0.853800
# 10  {'criterion': 'absolute_error', 'max_features'...           0.857938
# 11  {'criterion': 'absolute_error', 'max_features'...           0.859481
# 12  {'criterion': 'poisson', 'max_features': None,...                NaN
# 13  {'criterion': 'poisson', 'max_features': None,...                NaN
# 14  {'criterion': 'poisson', 'max_features': 'sqrt...                NaN
# 15  {'criterion': 'poisson', 'max_features': 'sqrt...                NaN
# 16  {'criterion': 'poisson', 'max_features': 'log2...                NaN
# 17  {'criterion': 'poisson', 'max_features': 'log2...                NaN
# 18  {'criterion': 'friedman_mse', 'max_features': ...           0.867701
# 19  {'criterion': 'friedman_mse', 'max_features': ...           0.864635
# 20  {'criterion': 'friedman_mse', 'max_features': ...           0.860094
# 21  {'criterion': 'friedman_mse', 'max_features': ...           0.862521
# 22  {'criterion': 'friedman_mse', 'max_features': ...           0.857706
# 23  {'criterion': 'friedman_mse', 'max_features': ...           0.867842
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0                 NaN                NaN                NaN
# 1                 NaN                NaN                NaN
# 2                 NaN                NaN                NaN
# 3                 NaN                NaN                NaN
# 4                 NaN                NaN                NaN
# 5                 NaN                NaN                NaN
# 6            0.768991           0.796946           0.800033
# 7            0.777470           0.793851           0.801850
# 8            0.796810           0.809105           0.808905
# 9            0.788390           0.809782           0.819856
# 10           0.783694           0.807162           0.819447
# 11           0.786270           0.808488           0.821980
# 12                NaN                NaN                NaN
# 13                NaN                NaN                NaN
# 14                NaN                NaN                NaN
# 15                NaN                NaN                NaN
# 16                NaN                NaN                NaN
# 17                NaN                NaN                NaN
# 18           0.766786           0.811448           0.796444
# 19           0.766801           0.809316           0.803343
# 20           0.794919           0.799913           0.820271
# 21           0.791247           0.808403           0.825742
# 22           0.792424           0.814231           0.820502
# 23           0.793414           0.812302           0.830462
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0                 NaN              NaN             NaN               13
# 1                 NaN              NaN             NaN               13
# 2                 NaN              NaN             NaN               13
# 3                 NaN              NaN             NaN               13
# 4                 NaN              NaN             NaN               13
# 5                 NaN              NaN             NaN               13
# 6            0.768717         0.795874        0.027788               12
# 7            0.765193         0.796298        0.026652               11
# 8            0.768455         0.806723        0.026365                8
# 9            0.769473         0.808260        0.028670                6
# 10           0.771584         0.807965        0.030141                7
# 11           0.767678         0.808780        0.031436                4
# 12                NaN              NaN             NaN               13
# 13                NaN              NaN             NaN               13
# 14                NaN              NaN             NaN               13
# 15                NaN              NaN             NaN               13
# 16                NaN              NaN             NaN               13
# 17                NaN              NaN             NaN               13
# 18           0.769048         0.802285        0.036776               10
# 19           0.768702         0.802559        0.035566                9
# 20           0.767341         0.808508        0.030831                5
# 21           0.771406         0.811864        0.031089                2
# 22           0.766894         0.810351        0.030234                3
# 23           0.772874         0.815379        0.032491                1

# %%
print(' R_score for best parameter{}:'.format(grid.best_params_))
# Out:
#  R_score for best parameter{'criterion': 'friedman_mse', 'max_features': 'log2', 'n_estimators': 100}:

# %%
grid_predictions = grid.predict(X_test)

# %%
#R_Score:

from sklearn.metrics import r2_score
R_score=r2_score(Y_test,grid_predictions)
R_score
# Out:
# 0.8699075558706135

# %%
import pickle
filename="Standard_Scaler.pkl"
pickle.dump(sc,open(filename,'wb'))
scx=pickle.load(open('Standard_Scaler.pkl','rb'))

# %%
import pickle
filename="finalized_model_Random_Forest_2.sav"
pickle.dump(grid,open(filename,'wb'))

# %%
Preinput=scx.transform([[23,25.70,1,0,1]])
Preinput
# Out:
# C:\Users\sswat\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[-1.17608405, -0.81068024, -0.06746417, -0.97676557,  1.98149332]])

# %%
loaded_model=pickle.load(open("finalized_model_Random_Forest_2.sav",'rb'))
Result=loaded_model.predict(Preinput)
print("Result={}".format(Result))
# Out:
# Result=[0.3603281]

# %%
import pickle
filename="Standard_Scaler_XY.pkl"
pickle.dump(scy,open(filename,'wb'))
ssxy=pickle.load(open('Standard_Scaler_XY.pkl','rb'))

# %%
Preoutput=ssxy.inverse_transform([Result])
Preoutput
# Out:
# array([[17511.3666701]])
